# %% [markdown]
# # Named Entity Recognition(NER)
# * used NLTK to analyze news

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.tokenize import TreebankWordTokenizer
from nltk.tag import pos_tag
from nltk import ne_chunk, Tree
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to /Users/cheng-
# [nltk_data]     shanhsieh/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/cheng-shanhsieh/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to /Users/cheng-
# [nltk_data]     shanhsieh/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /Users/cheng-
# [nltk_data]     shanhsieh/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
f = open('neverStopsApologising.txt','r')
ex = f.readlines()
f.close()
len(ex)
# Out:
# 43

# %%
strEx = " ".join(str(x) for x in ex)

# %%
def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

# %%
sent = preprocess(strEx)
sent
# Out:
# [('the', 'DT'),
#  ('island', 'NN'),
#  ('that', 'WDT'),
#  ('never', 'RB'),
#  ('stops', 'VBZ'),
#  ('apologising', 'VBG'),
#  ('Preserving', 'VBG'),
#  ('social', 'JJ'),
#  ('cohesion', 'NN'),
#  ('at', 'IN'),
#  ('all', 'DT'),
#  ('costs', 'NNS'),
#  ('is', 'VBZ'),
#  ('still', 'RB'),
#  ('the', 'DT'),
#  ('bedrock', 'NN'),
#  ('of', 'IN'),
#  ('Taiwan', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBZ'),
#  ('social', 'JJ'),
#  ('morality', 'NN'),
#  ('.', '.'),
#  ('Here', 'RB'),
#  (',', ','),
#  ('placing', 'VBG'),
#  ('the', 'DT'),
#  ('larger', 'JJR'),
#  ('clan', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('society', 'NN'),
#  (',', ','),
#  ('before', 'IN'),
#  ('yourself', 'PRP'),
#  (',', ','),
#  ('the', 'DT'),
#  ('individual', 'NN'),
#  (',', ','),
#  ('is', 'VBZ'),
#  ('key', 'JJ'),
#  ('.', '.'),
#  ('By', 'IN'),
#  ('Leslie', 'NNP'),
#  ('Nguyen-Okwu', 'NNP'),
#  ('1', 'CD'),
#  ('November', 'NNP'),
#  ('2018', 'CD'),
#  ('Yun-Tzai', 'NNP'),
#  ('Lee', 'NNP'),
#  ('and', 'CC'),
#  ('Joanne', 'NNP'),
#  ('Chen', 'NNP'),
#  ('are', 'VBP'),
#  ('one', 'CD'),
#  ('of', 'IN'),
#  ('those', 'DT'),
#  ('sickening', 'VBG'),
#  ('couples', 'NNS'),
#  ('that', 'WDT'),
#  ('finish', 'VBP'),
#  ('each', 'DT'),
#  ('other', 'JJ'),
#  ('’', 'JJ'),
#  ('s', 'NN'),
#  ('sentences', 'NNS'),
#  (',', ','),
#  ('lace', 'VBP'),
#  ('their', 'PRP$'),
#  ('fingers', 'NNS'),
#  ('together', 'RB'),
#  ('and', 'CC'),
#  ('just', 'RB'),
#  ('won', 'VBD'),
#  ('’', 'JJ'),
#  ('t', 'NN'),
#  ('stop', 'NN'),
#  ('oozing', 'VBG'),
#  ('adorable', 'JJ'),
#  ('.', '.'),
#  ('But', 'CC'),
#  ('the', 'DT'),
#  ('three', 'CD'),
#  ('little', 'JJ'),
#  ('words', 'NNS'),
#  ('‘', 'VBP'),
#  ('I', 'PRP'),
#  ('love', 'VBP'),
#  ('you', 'PRP'),
#  ('’', 'VBP'),
#  ('don', 'JJ'),
#  ('’', 'NNP'),
#  ('t', 'NN'),
#  ('come', 'NN'),
#  ('as', 'IN'),
#  ('easily', 'RB'),
#  ('to', 'TO'),
#  ('Lee', 'NNP'),
#  ('as', 'IN'),
#  ('they', 'PRP'),
#  ('do', 'VBP'),
#  ('to', 'TO'),
#  ('his', 'PRP$'),
#  ('fiancée', 'NN'),
#  ('Chen', 'NNP'),
#  ('.', '.'),
#  ('His', 'PRP$'),
#  ('face', 'NN'),
#  ('turns', 'VBZ'),
#  ('beetroot-red', 'JJ'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('thought', 'NN'),
#  ('of', 'IN'),
#  ('uttering', 'VBG'),
#  ('the', 'DT'),
#  ('phase', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('causes', 'VBZ'),
#  ('him', 'PRP'),
#  ('to', 'TO'),
#  ('feel', 'VB'),
#  ('‘', 'JJ'),
#  ('buhaoyisi', 'NN'),
#  ('’', 'NNP'),
#  ('(', '('),
#  ('pronounced', 'JJ'),
#  ('‘', 'IN'),
#  ('boo-how-eee-suh', 'JJ'),
#  ('’', 'NN'),
#  (')', ')'),
#  ('–', 'VBZ'),
#  ('one', 'CD'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('many', 'JJ'),
#  ('ways', 'NNS'),
#  ('to', 'TO'),
#  ('feel', 'VB'),
#  ('mortified', 'JJ'),
#  ('or', 'CC'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('sorry', 'VBN'),
#  ('in', 'IN'),
#  ('Taiwan', 'NNP'),
#  ('.', '.'),
#  ('“', 'VBZ'),
#  ('Most', 'JJS'),
#  ('people', 'NNS'),
#  ('here', 'RB'),
#  ('will', 'MD'),
#  ('feel', 'VB'),
#  ('this', 'DT'),
#  ('way', 'NN'),
#  (',', ','),
#  ('”', 'NNP'),
#  ('Lee', 'NNP'),
#  ('said', 'VBD'),
#  ('.', '.'),
#  ('Welcome', 'NNP'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('linguistic', 'JJ'),
#  ('minefield', 'NN'),
#  ('of', 'IN'),
#  ('apologising', 'VBG'),
#  ('in', 'IN'),
#  ('Taiwan', 'NNP'),
#  (',', ','),
#  ('where', 'WRB'),
#  ('simply', 'RB'),
#  ('saying', 'VBG'),
#  ('‘', 'NNP'),
#  ('buhaoyisi', 'NN'),
#  ('’', 'NN'),
#  ('can', 'MD'),
#  ('open', 'VB'),
#  ('a', 'DT'),
#  ('Pandora', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('Box', 'NNP'),
#  ('of', 'IN'),
#  ('profuse', 'NN'),
#  ('politeness', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('word', 'NN'),
#  ('is', 'VBZ'),
#  ('made', 'VBN'),
#  ('up', 'IN'),
#  ('of', 'IN'),
#  ('four', 'CD'),
#  ('characters', 'NNS'),
#  ('that', 'WDT'),
#  ('literally', 'RB'),
#  ('translate', 'VBP'),
#  ('to', 'TO'),
#  ('‘', 'VB'),
#  ('bad', 'JJ'),
#  ('meaning', 'VBG'),
#  ('’', 'NN'),
#  ('or', 'CC'),
#  ('‘', 'VB'),
#  ('bad', 'JJ'),
#  ('feeling', 'NN'),
#  ('’', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('serves', 'VBZ'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('tidy', 'NN'),
#  ('catch-all', 'NN'),
#  ('that', 'WDT'),
#  ('can', 'MD'),
#  ('be', 'VB'),
#  ('deployed', 'VBN'),
#  ('in', 'IN'),
#  ('all', 'DT'),
#  ('kinds', 'NNS'),
#  ('of', 'IN'),
#  ('situations', 'NNS'),
#  (',', ','),
#  ('from', 'IN'),
#  ('meekly', 'JJ'),
#  ('catching', 'VBG'),
#  ('a', 'DT'),
#  ('waiter', 'NN'),
#  ('’', 'NN'),
#  ('s', 'JJ'),
#  ('attention', 'NN'),
#  ('to', 'TO'),
#  ('expressing', 'VBG'),
#  ('a', 'DT'),
#  ('guilt-ridden', 'JJ'),
#  ('apology', 'NN'),
#  ('to', 'TO'),
#  ('your', 'PRP$'),
#  ('boss', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('paralysing', 'VBG'),
#  ('feeling', 'NN'),
#  ('that', 'WDT'),
#  ('washes', 'VBZ'),
#  ('over', 'RP'),
#  ('you', 'PRP'),
#  ('as', 'IN'),
#  ('you', 'PRP'),
#  ('struggle', 'VBP'),
#  ('to', 'TO'),
#  ('confess', 'VB'),
#  ('your', 'PRP$'),
#  ('love', 'NN'),
#  ('.', '.'),
#  ('Saying', 'VBG'),
#  ('‘', 'JJ'),
#  ('buhaoyisi', 'NN'),
#  ('’', 'NN'),
#  ('in', 'IN'),
#  ('Taiwan', 'NNP'),
#  ('can', 'MD'),
#  ('open', 'VB'),
#  ('a', 'DT'),
#  ('Pandora', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('Box', 'NNP'),
#  ('of', 'IN'),
#  ('profuse', 'NN'),
#  ('politeness', 'NN'),
#  ('You', 'PRP'),
#  ('may', 'MD'),
#  ('also', 'RB'),
#  ('be', 'VB'),
#  ('interested', 'JJ'),
#  ('in', 'IN'),
#  (':', ':'),
#  ('•', 'VB'),
#  ('The', 'DT'),
#  ('complex', 'JJ'),
#  ('art', 'NN'),
#  ('of', 'IN'),
#  ('apology', 'NN'),
#  ('in', 'IN'),
#  ('Japan', 'NNP'),
#  ('•', 'NNP'),
#  ('Where', 'NNP'),
#  ('being', 'VBG'),
#  ('nice', 'JJ'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('law', 'NN'),
#  ('•', 'VBZ'),
#  ('The', 'DT'),
#  ('country', 'NN'),
#  ('that', 'WDT'),
#  ('loves', 'VBZ'),
#  ('to', 'TO'),
#  ('give', 'VB'),
#  ('Buhaoyisi', 'NNP'),
#  ('is', 'VBZ'),
#  ('forever', 'RB'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('lips', 'NNS'),
#  ('of', 'IN'),
#  ('Taiwanese', 'NNP'),
#  (',', ','),
#  ('according', 'VBG'),
#  ('to', 'TO'),
#  ('Prof', 'NNP'),
#  ('Chia-ju', 'NNP'),
#  ('Chang', 'NNP'),
#  (',', ','),
#  ('Chinese', 'NNP'),
#  ('professor', 'NN'),
#  ('at', 'IN'),
#  ('Brooklyn', 'NNP'),
#  ('College', 'NNP'),
#  ('City', 'NNP'),
#  ('University', 'NNP'),
#  ('of', 'IN'),
#  ('New', 'NNP'),
#  ('York', 'NNP'),
#  ('.', '.'),
#  ('“', 'NN'),
#  ('We', 'PRP'),
#  ('use', 'VBP'),
#  ('it', 'PRP'),
#  ('all', 'PDT'),
#  ('the', 'DT'),
#  ('time', 'NN'),
#  ('as', 'IN'),
#  ('Taiwan', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('verbally', 'RB'),
#  ('polite', 'JJ'),
#  ('culture', 'NN'),
#  ('.', '.'),
#  ('So', 'RB'),
#  (',', ','),
#  ('we', 'PRP'),
#  ('use', 'VBP'),
#  ('it', 'PRP'),
#  ('when', 'WRB'),
#  ('we', 'PRP'),
#  ('interrupt', 'VBP'),
#  ('people', 'NNS'),
#  ('or', 'CC'),
#  ('asking', 'VBG'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('favour', 'NN'),
#  ('.', '.'),
#  ('We', 'PRP'),
#  ('can', 'MD'),
#  ('even', 'RB'),
#  ('use', 'VB'),
#  ('it', 'PRP'),
#  ('to', 'TO'),
#  ('start', 'VB'),
#  ('a', 'DT'),
#  ('conversation.', 'NN'),
#  ('”', 'NN'),
#  ('Buhaoyisi', 'NNP'),
#  ('is', 'VBZ'),
#  ('often', 'RB'),
#  ('spoken', 'VBN'),
#  ('so', 'RB'),
#  ('fast', 'RB'),
#  ('that', 'IN'),
#  ('it', 'PRP'),
#  ('comes', 'VBZ'),
#  ('out', 'RP'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('slurry', 'NN'),
#  ('of', 'IN'),
#  ('consonants', 'NNS'),
#  ('that', 'WDT'),
#  ('sounds', 'VBZ'),
#  ('like', 'IN'),
#  ('gibberish', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('unsuspecting', 'JJ'),
#  ('ear', 'NN'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('unlike', 'IN'),
#  ('‘', 'NNP'),
#  ('Entschuldigung', 'NNP'),
#  ('’', 'NNP'),
#  ('in', 'IN'),
#  ('German', 'NNP'),
#  ('or', 'CC'),
#  ('‘', 'NNP'),
#  ('excuse', 'IN'),
#  ('me', 'PRP'),
#  ('’', 'VBP'),
#  ('in', 'IN'),
#  ('English', 'NNP'),
#  (',', ','),
#  ('translating', 'VBG'),
#  ('‘', 'JJ'),
#  ('buhaoyisi', 'NN'),
#  ('’', 'NNP'),
#  ('is', 'VBZ'),
#  ('no', 'DT'),
#  ('simple', 'JJ'),
#  ('task', 'NN'),
#  (',', ','),
#  ('says', 'VBZ'),
#  ('Ouyu', 'NNP'),
#  ('Yang', 'NNP'),
#  (',', ','),
#  ('a', 'DT'),
#  ('teacher', 'NN'),
#  ('at', 'IN'),
#  ('National', 'NNP'),
#  ('Taiwan', 'NNP'),
#  ('University', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBZ'),
#  ('Chinese', 'JJ'),
#  ('Language', 'NNP'),
#  ('Division', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('Western', 'JJ'),
#  ('notion', 'NN'),
#  ('of', 'IN'),
#  ('‘', 'NNP'),
#  ('sorry', 'NN'),
#  ('’', 'NN'),
#  ('is', 'VBZ'),
#  ('far', 'RB'),
#  ('too', 'RB'),
#  ('limited', 'JJ'),
#  ('to', 'TO'),
#  ('express', 'VB'),
#  ('all', 'PDT'),
#  ('the', 'DT'),
#  ('social', 'JJ'),
#  ('graces', 'NNS'),
#  ('and', 'CC'),
#  ('good', 'JJ'),
#  ('form', 'NN'),
#  ('that', 'WDT'),
#  ('weigh', 'VBP'),
#  ('down', 'RP'),
#  ('on', 'IN'),
#  ('this', 'DT'),
#  ('loaded', 'JJ'),
#  ('expression', 'NN'),
#  (';', ':'),
#  ('buhaoyisi', 'CC'),
#  ('can', 'MD'),
#  ('also', 'RB'),
#  ('be', 'VB'),
#  ('a', 'DT'),
#  ('feeling', 'NN'),
#  (',', ','),
#  ('a', 'DT'),
#  ('sensation', 'NN'),
#  (',', ','),
#  ('a', 'DT'),
#  ('code', 'NN'),
#  ('of', 'IN'),
#  ('conduct', 'NN'),
#  ('and', 'CC'),
#  ('a', 'DT'),
#  ('whole', 'JJ'),
#  ('system', 'NN'),
#  ('of', 'IN'),
#  ('thought', 'NN'),
#  ('that', 'WDT'),
#  ('permeates', 'VBZ'),
#  ('Taiwanese', 'JJ'),
#  ('culture', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('Western', 'JJ'),
#  ('notion', 'NN'),
#  ('of', 'IN'),
#  ('‘', 'NNP'),
#  ('sorry', 'NN'),
#  ('’', 'NN'),
#  ('is', 'VBZ'),
#  ('far', 'RB'),
#  ('too', 'RB'),
#  ('limited', 'JJ'),
#  ('to', 'TO'),
#  ('express', 'VB'),
#  ('all', 'PDT'),
#  ('the', 'DT'),
#  ('social', 'JJ'),
#  ('graces', 'NNS'),
#  ('and', 'CC'),
#  ('good', 'JJ'),
#  ('form', 'NN'),
#  ('that', 'WDT'),
#  ('weigh', 'VBP'),
#  ('down', 'RP'),
#  ('on', 'IN'),
#  ('this', 'DT'),
#  ('loaded', 'JJ'),
#  ('expression', 'NN'),
#  ('Ride', 'NNP'),
#  ('the', 'DT'),
#  ('subway', 'NN'),
#  ('in', 'IN'),
#  ('Taipei', 'NNP'),
#  ('and', 'CC'),
#  ('you', 'PRP'),
#  ('’', 'VBP'),
#  ('ll', 'JJ'),
#  ('hear', 'VBP'),
#  ('a', 'DT'),
#  ('cacophonous', 'JJ'),
#  ('chorus', 'NN'),
#  ('of', 'IN'),
#  ('‘', 'NNP'),
#  ('buhaoyisi', 'NN'),
#  ('’', 'NNP'),
#  ('as', 'IN'),
#  ('passengers', 'NNS'),
#  ('gingerly', 'RB'),
#  ('nudge', 'VBP'),
#  ('past', 'JJ'),
#  ('others', 'NNS'),
#  ('in', 'IN'),
#  ('humble', 'JJ'),
#  ('deference', 'NN'),
#  ('.', '.'),
#  ('Enter', 'VB'),
#  ('a', 'DT'),
#  ('classroom', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('you', 'PRP'),
#  ('’', 'VBP'),
#  ('ll', 'JJ'),
#  ('see', 'NN'),
#  ('students', 'NNS'),
#  ('start', 'VBP'),
#  ('and', 'CC'),
#  ('end', 'VBP'),
#  ('each', 'DT'),
#  ('question', 'NN'),
#  ('with', 'IN'),
#  ('‘', 'JJ'),
#  ('buhaoyisi', 'NN'),
#  ('’', 'NNP'),
#  (',', ','),
#  ('dripping', 'VBG'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('sense', 'NN'),
#  ('of', 'IN'),
#  ('indebtedness', 'NN'),
#  ('and', 'CC'),
#  ('gratefulness', 'NN'),
#  ('even', 'RB'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('discussion', 'NN'),
#  ('continues', 'VBZ'),
#  ('.', '.'),
#  ('Open', 'VB'),
#  ('an', 'DT'),
#  ('email', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('line', 'NN'),
#  ('will', 'MD'),
#  ('usually', 'RB'),
#  ('be', 'VB'),
#  ('‘', 'JJ'),
#  ('Buhaoyisi', 'NNP'),
#  ('’', 'NNP'),
#  ('–', 'NNP'),
#  ('implying', 'VBG'),
#  ('‘', 'JJ'),
#  ('sorry', 'NN'),
#  ('to', 'TO'),
#  ('slightly', 'RB'),
#  ('bother', 'VB'),
#  ('you', 'PRP'),
#  ('’', 'VBP'),
#  ('–', 'VB'),
#  ('even', 'RB'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('smallest', 'JJS'),
#  ('of', 'IN'),
#  ('favours', 'NN'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('if', 'IN'),
#  ('a', 'DT'),
#  ('dear', 'JJ'),
#  ('cousin', 'NN'),
#  ('gives', 'VBZ'),
#  ('you', 'PRP'),
#  ('a', 'DT'),
#  ('gift', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('correct', 'JJ'),
#  ('response', 'NN'),
#  ('isn', 'NN'),
#  ('’', 'NNP'),
#  ('t', 'NN'),
#  ('‘', 'NNP'),
#  ('thank', 'NN'),
#  ('you', 'PRP'),
#  ('’', 'VBP'),
#  (',', ','),
#  ('but', 'CC'),
#  ('rather', 'RB'),
#  (',', ','),
#  ('‘', 'VB'),
#  ('buhaoyisi', 'NN'),
#  ('’', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('inconvenience', 'NN'),
#  ('I', 'PRP'),
#  ('’', 'VBP'),
#  ('ve', 'NNS'),
#  ('caused', 'VBD'),
#  ('you', 'PRP'),
#  ('.', '.'),
#  ('For', 'IN'),
#  ('the', 'DT'),
#  ('uninitiated', 'JJ'),
#  ('outsider', 'NN'),
#  (',', ','),
#  ('Taiwan', 'NNP'),
#  ('may', 'MD'),
#  ('seem', 'VB'),
#  ('like', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'VBZ'),
#  ('most', 'JJS'),
#  ('apologetic', 'JJ'),
#  ('country', 'NN'),
#  (',', ','),
#  ('a', 'DT'),
#  ('nation', 'NN'),
#  ('obsessed', 'VBN'),
#  ('with', 'IN'),
#  ('saying', 'VBG'),
#  ('sorry', 'JJ'),
#  ('–', 'NNS'),
#  ('but', 'CC'),
#  ('in', 'IN'),
#  ('fact', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('culture', 'NN'),
#  ('of', 'IN'),
#  ('buhaoyisi', 'NN'),
#  ('reveals', 'NNS'),
#  ('a', 'DT'),
#  ('lot', 'NN'),
#  ('about', 'IN'),
#  ('the', 'DT'),
#  ('islands', 'NNS'),
#  ('’', 'VBP'),
#  ('hidden', 'JJ'),
#  ('layers', 'NNS'),
#  ('of', 'IN'),
#  ('modesty', 'NN'),
#  ('and', 'CC'),
#  ('shyness', 'NN'),
#  ('.', '.'),
#  ('Taiwan', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('verbally', 'RB'),
#  ('polite', 'JJ'),
#  ('culture', 'NN'),
#  ('(', '('),
#  ('Credit', 'NNP'),
#  (':', ':'),
#  ('Credit', 'NN'),
#  (':', ':'),
#  ('James', 'NNP'),
#  ('Brooks/Alamy', 'NNP'),
#  (')', ')'),
#  ('Prof', 'NNP'),
#  ('Chia-ju', 'NNP'),
#  ('Chang', 'NNP'),
#  (':', ':'),
#  ('“', 'NN'),
#  ('We', 'PRP'),
#  ('use', 'VBP'),
#  ('[', 'JJ'),
#  ('buhaoyisi', 'NN'),
#  (']', 'NNP'),
#  ('all', 'PDT'),
#  ('the', 'DT'),
#  ('time', 'NN'),
#  ('as', 'IN'),
#  ('Taiwan', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('verbally', 'RB'),
#  ('polite', 'JJ'),
#  ('culture', 'NN'),
#  ('.', '.'),
#  ('We', 'PRP'),
#  ('can', 'MD'),
#  ('even', 'RB'),
#  ('use', 'VB'),
#  ('it', 'PRP'),
#  ('to', 'TO'),
#  ('start', 'VB'),
#  ('a', 'DT'),
#  ('conversation', 'NN'),
#  ('”', 'NNP'),
#  ('(', '('),
#  ('Credit', 'NNP'),
#  (':', ':'),
#  ('James', 'NNP'),
#  ('Brooks/Alamy', 'NNP'),
#  (')', ')'),
#  ('Decades', 'NNP'),
#  ('of', 'IN'),
#  ('Japanese', 'JJ'),
#  ('colonisation', 'NN'),
#  (',', ','),
#  ('as', 'RB'),
#  ('well', 'RB'),
#  ('as', 'IN'),
#  ('moral', 'JJ'),
#  ('teachings', 'NNS'),
#  ('of', 'IN'),
#  ('Confucianism', 'NNP'),
#  (',', ','),
#  ('have', 'VBP'),
#  ('played', 'VBN'),
#  ('a', 'DT'),
#  ('huge', 'JJ'),
#  ('hand', 'NN'),
#  ('in', 'IN'),
#  ('shaping', 'VBG'),
#  ('Taiwan', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('extreme', 'JJ'),
#  ('apology', 'JJ'),
#  ('culture', 'NN'),
#  ('to', 'TO'),
#  ('what', 'WP'),
#  ('you', 'PRP'),
#  ('see', 'VBP'),
#  ('and', 'CC'),
#  ('hear', 'VBP'),
#  ('today', 'NN'),
#  (',', ','),
#  ('according', 'VBG'),
#  ('to', 'TO'),
#  ('Khin-huann', 'NNP'),
#  ('Li', 'NNP'),
#  (',', ','),
#  ('sociolinguistics', 'NN'),
#  ('professor', 'NN'),
#  ('emeritus', 'NN'),
#  ('at', 'IN'),
#  ('National', 'NNP'),
#  ('Taiwan', 'NNP'),
#  ('Normal', 'NNP'),
#  ('University', 'NNP'),
#  ('.', '.'),
#  ('Although', 'IN'),
#  ('the', 'DT'),
#  ('phrase', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'NN'),
#  ('exact', 'NN'),
#  ('origins', 'NNS'),
#  ('are', 'VBP'),
#  ('unknown', 'JJ'),
#  (',', ','),
#  ('Li', 'NNP'),
#  ('and', 'CC'),
#  ('other', 'JJ'),
#  ('linguists', 'NNS'),
#  ('theorise', 'VBP'),
#  ('that', 'IN'),
#  ('it', 'PRP'),
#  ('is', 'VBZ'),
#  ('largely', 'RB'),
#  ('a', 'DT'),
#  ('product', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('millennia-old', 'JJ'),
#  ('Confucian', 'JJ'),
#  ('notion', 'NN'),
#  ('of', 'IN'),
#  ('harmony', 'NN'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('centres', 'VBZ'),
#  ('on', 'IN'),
#  ('maintaining', 'VBG'),
#  ('interpersonal', 'JJ'),
#  ('relationships', 'NNS'),
#  ('rather', 'RB'),
#  ('than', 'IN'),
#  ('individual', 'JJ'),
#  ('ones', 'NNS'),
#  ('.', '.'),
#  ('Preserving', 'VBG'),
#  ('social', 'JJ'),
#  ('cohesion', 'NN'),
#  ('at', 'IN'),
#  ('all', 'DT'),
#  ('costs', 'NNS'),
#  ('is', 'VBZ'),
#  ('still', 'RB'),
#  ('the', 'DT'),
#  ('bedrock', 'NN'),
#  ('of', 'IN'),
#  ('Taiwan', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBZ'),
#  ('social', 'JJ'),
#  ('morality', 'NN'),
#  (';', ':'),
#  ('placing', 'VBG'),
#  ('the', 'DT'),
#  ('larger', 'JJR'),
#  ('clan', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('society', 'NN'),
#  (',', ','),
#  ('before', 'IN'),
#  ('yourself', 'PRP'),
#  (',', ','),
#  ('the', 'DT'),
#  ('individual', 'NN'),
#  (',', ','),
#  ('is', 'VBZ'),
#  ('key', 'JJ'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('addition', 'NN'),
#  (',', ','),
#  ('part', 'NN'),
#  ('of', 'IN'),
#  ('Taiwan', 'NNP'),
#  ("'s", 'POS'),
#  ('buhaoyisi', 'JJ'),
#  ('culture', 'NN'),
#  ('is', 'VBZ'),
#  ('heavily', 'RB'),
#  ('influenced', 'VBN'),
#  ('from', 'IN'),
#  ('Japan', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('sumimasen', 'JJ'),
#  ('apology', 'JJ'),
#  ('culture', 'NN'),
#  (',', ','),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('two', 'CD'),
#  ('sharing', 'VBG'),
#  ('a', 'DT'),
#  ('deep', 'JJ'),
#  ('history', 'NN'),
#  ('.', '.'),
#  ('Overall', 'JJ'),
#  (',', ','),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('habit', 'NN'),
#  (',', ','),
#  ('saying', 'VBG'),
#  ('buhaoyisi', 'NN'),
#  ('often', 'RB'),
#  ('helps', 'VBZ'),
#  ('confrontations', 'NNS'),
#  ('from', 'IN'),
#  ('escalating', 'VBG'),
#  ('further', 'RB'),
#  (',', ','),
#  ('Li', 'NNP'),
#  ('said', 'VBD'),
#  ('.', '.'),
#  ('“', 'JJ'),
#  ('Traditional', 'NNP'),
#  ('Taiwanese', 'JJ'),
#  ('culture', 'NN'),
#  ('is', 'VBZ'),
#  ('like', 'IN'),
#  ('that', 'DT'),
#  ('–', 'VBZ'),
#  ('more', 'JJR'),
#  ('delicate', 'JJ'),
#  ('and', 'CC'),
#  ('thinking', 'NN'),
#  ('of', 'IN'),
#  ('other', 'JJ'),
#  ('people', 'NNS'),
#  (',', ','),
#  ('trying', 'VBG'),
#  ('to', 'TO'),
#  ('keep', 'VB'),
#  ('polite', 'JJ'),
#  ('relationships', 'NNS'),
#  ('with', 'IN'),
#  ('others', 'NNS'),
#  (',', ','),
#  ('”', 'VB'),
#  ('he', 'PRP'),
#  ('explained', 'VBD'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('culture', 'NN'),
#  ('of', 'IN'),
#  ('buhaoyisi', 'NN'),
#  ('reveals', 'NNS'),
#  ('a', 'DT'),
#  ('lot', 'NN'),
#  ('about', 'IN'),
#  ('Taiwan', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('hidden', 'JJ'),
#  ('layers', 'NNS'),
#  ('of', 'IN'),
#  ('modesty', 'NN'),
#  ('and', 'CC'),
#  ('shyness', 'NN'),
#  ('(', '('),
#  ('Credit', 'NNP'),
#  (':', ':'),
#  ('Credit', 'NN'),
#  (':', ':'),
#  ('Sean', 'JJ'),
#  ('Pavone/Alamy', 'NNP'),
#  (')', ')'),
#  ('The', 'DT'),
#  ('culture', 'NN'),
#  ('of', 'IN'),
#  ('buhaoyisi', 'NN'),
#  ('reveals', 'NNS'),
#  ('a', 'DT'),
#  ('lot', 'NN'),
#  ('about', 'IN'),
#  ('Taiwan', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('hidden', 'JJ'),
#  ('layers', 'NNS'),
#  ('of', 'IN'),
#  ('modesty', 'NN'),
#  ('and', 'CC'),
#  ('shyness', 'NN'),
#  ('(', '('),
#  ('Credit', 'NNP'),
#  (':', ':'),
#  ('Sean', 'JJ'),
#  ('Pavone/Alamy', 'NNP'),
#  (')', ')'),
#  ('On', 'IN'),
#  ('the', 'DT'),
#  ('one', 'CD'),
#  ('hand', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('expression', 'NN'),
#  ('carries', 'VBZ'),
#  ('an', 'DT'),
#  ('air', 'NN'),
#  ('of', 'IN'),
#  ('submissiveness', 'NN'),
#  ('and', 'CC'),
#  ('hyper', 'NN'),
#  ('decorum', 'NN'),
#  (',', ','),
#  ('but', 'CC'),
#  ('on', 'IN'),
#  ...]

# %%
NER = ne_chunk(nltk.pos_tag(word_tokenize(strEx)), binary=False)

# %%
type(NER)
# Out:
# nltk.tree.Tree

# %%
print(NER)
# Out:
# (S
#   the/DT
#   island/NN
#   that/WDT
#   never/RB
#   stops/VBZ
#   apologising/VBG
#   Preserving/VBG
#   social/JJ
#   cohesion/NN
#   at/IN
#   all/DT
#   costs/NNS
#   is/VBZ
#   still/RB
#   the/DT
#   bedrock/NN
#   of/IN
#   (GPE Taiwan/NNP)
#   ’/NNP
#   s/VBZ
#   social/JJ
#   morality/NN
#   ./.
#   Here/RB
#   ,/,
#   placing/VBG
#   the/DT
#   larger/JJR
#   clan/NN
#   ,/,
#   the/DT
#   society/NN
#   ,/,
#   before/IN
#   yourself/PRP
#   ,/,
#   the/DT
#   individual/NN
#   ,/,
#   is/VBZ
#   key/JJ
#   ./.
#   By/IN
#   (PERSON Leslie/NNP)
#   Nguyen-Okwu/NNP
#   1/CD
#   November/NNP
#   2018/CD
#   Yun-Tzai/NNP
#   Lee/NNP
#   and/CC
#   (PERSON Joanne/NNP Chen/NNP)
#   are/VBP
#   one/CD
#   of/IN
#   those/DT
#   sickening/VBG
#   couples/NNS
#   that/WDT
#   finish/VBP
#   each/DT
#   other/JJ
#   ’/JJ
#   s/NN
#   sentences/NNS
#   ,/,
#   lace/VBP
#   their/PRP$
#   fingers/NNS
#   together/RB
#   and/CC
#   just/RB
#   won/VBD
#   ’/JJ
#   t/NN
#   stop/NN
#   oozing/VBG
#   adorable/JJ
#   ./.
#   But/CC
#   the/DT
#   three/CD
#   little/JJ
#   words/NNS
#   ‘/VBP
#   I/PRP
#   love/VBP
#   you/PRP
#   ’/VBP
#   don/JJ
#   ’/NNP
#   t/NN
#   come/NN
#   as/IN
#   easily/RB
#   to/TO
#   (PERSON Lee/NNP)
#   as/IN
#   they/PRP
#   do/VBP
#   to/TO
#   his/PRP$
#   fiancée/NN
#   (PERSON Chen/NNP)
#   ./.
#   His/PRP$
#   face/NN
#   turns/VBZ
#   beetroot-red/JJ
#   at/IN
#   the/DT
#   thought/NN
#   of/IN
#   uttering/VBG
#   the/DT
#   phase/NN
#   ,/,
#   and/CC
#   causes/VBZ
#   him/PRP
#   to/TO
#   feel/VB
#   ‘/JJ
#   buhaoyisi/NN
#   ’/NNP
#   (/(
#   pronounced/JJ
#   ‘/IN
#   boo-how-eee-suh/JJ
#   ’/NN
#   )/)
#   –/VBZ
#   one/CD
#   of/IN
#   the/DT
#   many/JJ
#   ways/NNS
#   to/TO
#   feel/VB
#   mortified/JJ
#   or/CC
#   to/TO
#   be/VB
#   sorry/VBN
#   in/IN
#   (GPE Taiwan/NNP)
#   ./.
#   “/VBZ
#   Most/JJS
#   people/NNS
#   here/RB
#   will/MD
#   feel/VB
#   this/DT
#   way/NN
#   ,/,
#   ”/NNP
#   (PERSON Lee/NNP)
#   said/VBD
#   ./.
#   Welcome/NNP
#   to/TO
#   the/DT
#   linguistic/JJ
#   minefield/NN
#   of/IN
#   apologising/VBG
#   in/IN
#   (GPE Taiwan/NNP)
#   ,/,
#   where/WRB
#   simply/RB
#   saying/VBG
#   ‘/NNP
#   buhaoyisi/NN
#   ’/NN
#   can/MD
#   open/VB
#   a/DT
#   (ORGANIZATION Pandora/NNP)
#   ’/NNP
#   s/VBD
#   Box/NNP
#   of/IN
#   profuse/NN
#   politeness/NN
#   ./.
#   The/DT
#   word/NN
#   is/VBZ
#   made/VBN
#   up/IN
#   of/IN
#   four/CD
#   characters/NNS
#   that/WDT
#   literally/RB
#   translate/VBP
#   to/TO
#   ‘/VB
#   bad/JJ
#   meaning/VBG
#   ’/NN
#   or/CC
#   ‘/VB
#   bad/JJ
#   feeling/NN
#   ’/NN
#   ,/,
#   and/CC
#   serves/VBZ
#   as/IN
#   a/DT
#   tidy/NN
#   catch-all/NN
#   that/WDT
#   can/MD
#   be/VB
#   deployed/VBN
#   in/IN
#   all/DT
#   kinds/NNS
#   of/IN
#   situations/NNS
#   ,/,
#   from/IN
#   meekly/JJ
#   catching/VBG
#   a/DT
#   waiter/NN
#   ’/NN
#   s/JJ
#   attention/NN
#   to/TO
#   expressing/VBG
#   a/DT
#   guilt-ridden/JJ
#   apology/NN
#   to/TO
#   your/PRP$
#   boss/NN
#   to/TO
#   the/DT
#   paralysing/VBG
#   feeling/NN
#   that/WDT
#   washes/VBZ
#   over/RP
#   you/PRP
#   as/IN
#   you/PRP
#   struggle/VBP
#   to/TO
#   confess/VB
#   your/PRP$
#   love/NN
#   ./.
#   Saying/VBG
#   ‘/JJ
#   buhaoyisi/NN
#   ’/NN
#   in/IN
#   (GPE Taiwan/NNP)
#   can/MD
#   open/VB
#   a/DT
#   (ORGANIZATION Pandora/NNP)
#   ’/NNP
#   s/VBD
#   Box/NNP
#   of/IN
#   profuse/NN
#   politeness/NN
#   You/PRP
#   may/MD
#   also/RB
#   be/VB
#   interested/JJ
#   in/IN
#   :/:
#   •/VB
#   The/DT
#   complex/JJ
#   art/NN
#   of/IN
#   apology/NN
#   in/IN
#   (GPE Japan/NNP)
#   •/NNP
#   Where/NNP
#   being/VBG
#   nice/JJ
#   is/VBZ
#   the/DT
#   law/NN
#   •/VBZ
#   The/DT
#   country/NN
#   that/WDT
#   loves/VBZ
#   to/TO
#   give/VB
#   (PERSON Buhaoyisi/NNP)
#   is/VBZ
#   forever/RB
#   on/IN
#   the/DT
#   lips/NNS
#   of/IN
#   (GPE Taiwanese/NNP)
#   ,/,
#   according/VBG
#   to/TO
#   (PERSON Prof/NNP)
#   Chia-ju/NNP
#   Chang/NNP
#   ,/,
#   (GPE Chinese/NNP)
#   professor/NN
#   at/IN
#   (ORGANIZATION Brooklyn/NNP College/NNP City/NNP University/NNP)
#   of/IN
#   (GPE New/NNP York/NNP)
#   ./.
#   “/NN
#   We/PRP
#   use/VBP
#   it/PRP
#   all/PDT
#   the/DT
#   time/NN
#   as/IN
#   (GPE Taiwan/NNP)
#   is/VBZ
#   a/DT
#   verbally/RB
#   polite/JJ
#   culture/NN
#   ./.
#   So/RB
#   ,/,
#   we/PRP
#   use/VBP
#   it/PRP
#   when/WRB
#   we/PRP
#   interrupt/VBP
#   people/NNS
#   or/CC
#   asking/VBG
#   of/IN
#   a/DT
#   favour/NN
#   ./.
#   We/PRP
#   can/MD
#   even/RB
#   use/VB
#   it/PRP
#   to/TO
#   start/VB
#   a/DT
#   conversation./NN
#   ”/NN
#   (PERSON Buhaoyisi/NNP)
#   is/VBZ
#   often/RB
#   spoken/VBN
#   so/RB
#   fast/RB
#   that/IN
#   it/PRP
#   comes/VBZ
#   out/RP
#   as/IN
#   a/DT
#   slurry/NN
#   of/IN
#   consonants/NNS
#   that/WDT
#   sounds/VBZ
#   like/IN
#   gibberish/NN
#   to/TO
#   the/DT
#   unsuspecting/JJ
#   ear/NN
#   ./.
#   And/CC
#   unlike/IN
#   ‘/NNP
#   Entschuldigung/NNP
#   ’/NNP
#   in/IN
#   (GPE German/NNP)
#   or/CC
#   ‘/NNP
#   excuse/IN
#   me/PRP
#   ’/VBP
#   in/IN
#   (GPE English/NNP)
#   ,/,
#   translating/VBG
#   ‘/JJ
#   buhaoyisi/NN
#   ’/NNP
#   is/VBZ
#   no/DT
#   simple/JJ
#   task/NN
#   ,/,
#   says/VBZ
#   (PERSON Ouyu/NNP Yang/NNP)
#   ,/,
#   a/DT
#   teacher/NN
#   at/IN
#   (ORGANIZATION National/NNP Taiwan/NNP University/NNP)
#   ’/NNP
#   s/VBZ
#   (GPE Chinese/JJ)
#   (ORGANIZATION Language/NNP Division/NNP)
#   ./.
#   The/DT
#   (LOCATION Western/JJ)
#   notion/NN
#   of/IN
#   ‘/NNP
#   sorry/NN
#   ’/NN
#   is/VBZ
#   far/RB
#   too/RB
#   limited/JJ
#   to/TO
#   express/VB
#   all/PDT
#   the/DT
#   social/JJ
#   graces/NNS
#   and/CC
#   good/JJ
#   form/NN
#   that/WDT
#   weigh/VBP
#   down/RP
#   on/IN
#   this/DT
#   loaded/JJ
#   expression/NN
#   ;/:
#   buhaoyisi/CC
#   can/MD
#   also/RB
#   be/VB
#   a/DT
#   feeling/NN
#   ,/,
#   a/DT
#   sensation/NN
#   ,/,
#   a/DT
#   code/NN
#   of/IN
#   conduct/NN
#   and/CC
#   a/DT
#   whole/JJ
#   system/NN
#   of/IN
#   thought/NN
#   that/WDT
#   permeates/VBZ
#   (GPE Taiwanese/JJ)
#   culture/NN
#   ./.
#   The/DT
#   (LOCATION Western/JJ)
#   notion/NN
#   of/IN
#   ‘/NNP
#   sorry/NN
#   ’/NN
#   is/VBZ
#   far/RB
#   too/RB
#   limited/JJ
#   to/TO
#   express/VB
#   all/PDT
#   the/DT
#   social/JJ
#   graces/NNS
#   and/CC
#   good/JJ
#   form/NN
#   that/WDT
#   weigh/VBP
#   down/RP
#   on/IN
#   this/DT
#   loaded/JJ
#   expression/NN
#   Ride/NNP
#   the/DT
#   subway/NN
#   in/IN
#   (GPE Taipei/NNP)
#   and/CC
#   you/PRP
#   ’/VBP
#   ll/JJ
#   hear/VBP
#   a/DT
#   cacophonous/JJ
#   chorus/NN
#   of/IN
#   ‘/NNP
#   buhaoyisi/NN
#   ’/NNP
#   as/IN
#   passengers/NNS
#   gingerly/RB
#   nudge/VBP
#   past/JJ
#   others/NNS
#   in/IN
#   humble/JJ
#   deference/NN
#   ./.
#   Enter/VB
#   a/DT
#   classroom/NN
#   ,/,
#   and/CC
#   you/PRP
#   ’/VBP
#   ll/JJ
#   see/NN
#   students/NNS
#   start/VBP
#   and/CC
#   end/VBP
#   each/DT
#   question/NN
#   with/IN
#   ‘/JJ
#   buhaoyisi/NN
#   ’/NNP
#   ,/,
#   dripping/VBG
#   with/IN
#   a/DT
#   sense/NN
#   of/IN
#   indebtedness/NN
#   and/CC
#   gratefulness/NN
#   even/RB
#   as/IN
#   the/DT
#   discussion/NN
#   continues/VBZ
#   ./.
#   Open/VB
#   an/DT
#   email/NN
#   ,/,
#   and/CC
#   the/DT
#   first/JJ
#   line/NN
#   will/MD
#   usually/RB
#   be/VB
#   ‘/JJ
#   (PERSON Buhaoyisi/NNP)
#   ’/NNP
#   –/NNP
#   implying/VBG
#   ‘/JJ
#   sorry/NN
#   to/TO
#   slightly/RB
#   bother/VB
#   you/PRP
#   ’/VBP
#   –/VB
#   even/RB
#   for/IN
#   the/DT
#   smallest/JJS
#   of/IN
#   favours/NN
#   ./.
#   And/CC
#   if/IN
#   a/DT
#   dear/JJ
#   cousin/NN
#   gives/VBZ
#   you/PRP
#   a/DT
#   gift/NN
#   ,/,
#   the/DT
#   correct/JJ
#   response/NN
#   isn/NN
#   ’/NNP
#   t/NN
#   ‘/NNP
#   thank/NN
#   you/PRP
#   ’/VBP
#   ,/,
#   but/CC
#   rather/RB
#   ,/,
#   ‘/VB
#   buhaoyisi/NN
#   ’/NN
#   for/IN
#   the/DT
#   inconvenience/NN
#   I/PRP
#   ’/VBP
#   ve/NNS
#   caused/VBD
#   you/PRP
#   ./.
#   For/IN
#   the/DT
#   uninitiated/JJ
#   outsider/NN
#   ,/,
#   (GPE Taiwan/NNP)
#   may/MD
#   seem/VB
#   like/IN
#   the/DT
#   world/NN
#   ’/NNP
#   s/VBZ
#   most/JJS
#   apologetic/JJ
#   country/NN
#   ,/,
#   a/DT
#   nation/NN
#   obsessed/VBN
#   with/IN
#   saying/VBG
#   sorry/JJ
#   –/NNS
#   but/CC
#   in/IN
#   fact/NN
#   ,/,
#   the/DT
#   culture/NN
#   of/IN
#   buhaoyisi/NN
#   reveals/NNS
#   a/DT
#   lot/NN
#   about/IN
#   the/DT
#   islands/NNS
#   ’/VBP
#   hidden/JJ
#   layers/NNS
#   of/IN
#   modesty/NN
#   and/CC
#   shyness/NN
#   ./.
#   (GPE Taiwan/NNP)
#   is/VBZ
#   a/DT
#   verbally/RB
#   polite/JJ
#   culture/NN
#   (/(
#   (ORGANIZATION Credit/NNP)
#   :/:
#   Credit/NN
#   :/:
#   (PERSON James/NNP)
#   Brooks/Alamy/NNP
#   )/)
#   Prof/NNP
#   Chia-ju/NNP
#   Chang/NNP
#   :/:
#   “/NN
#   We/PRP
#   use/VBP
#   [/JJ
#   buhaoyisi/NN
#   ]/NNP
#   all/PDT
#   the/DT
#   time/NN
#   as/IN
#   (GPE Taiwan/NNP)
#   is/VBZ
#   a/DT
#   verbally/RB
#   polite/JJ
#   culture/NN
#   ./.
#   We/PRP
#   can/MD
#   even/RB
#   use/VB
#   it/PRP
#   to/TO
#   start/VB
#   a/DT
#   conversation/NN
#   ”/NNP
#   (/(
#   (ORGANIZATION Credit/NNP)
#   :/:
#   (PERSON James/NNP)
#   Brooks/Alamy/NNP
#   )/)
#   Decades/NNP
#   of/IN
#   (GPE Japanese/JJ)
#   colonisation/NN
#   ,/,
#   as/RB
#   well/RB
#   as/IN
#   moral/JJ
#   teachings/NNS
#   of/IN
#   (GSP Confucianism/NNP)
#   ,/,
#   have/VBP
#   played/VBN
#   a/DT
#   huge/JJ
#   hand/NN
#   in/IN
#   shaping/VBG
#   (GPE Taiwan/NNP)
#   ’/NNP
#   s/VBD
#   extreme/JJ
#   apology/JJ
#   culture/NN
#   to/TO
#   what/WP
#   you/PRP
#   see/VBP
#   and/CC
#   hear/VBP
#   today/NN
#   ,/,
#   according/VBG
#   to/TO
#   Khin-huann/NNP
#   Li/NNP
#   ,/,
#   sociolinguistics/NN
#   professor/NN
#   emeritus/NN
#   at/IN
#   (ORGANIZATION National/NNP Taiwan/NNP Normal/NNP University/NNP)
#   ./.
#   Although/IN
#   the/DT
#   phrase/NN
#   ’/NNP
#   s/NN
#   exact/NN
#   origins/NNS
#   are/VBP
#   unknown/JJ
#   ,/,
#   (PERSON Li/NNP)
#   and/CC
#   other/JJ
#   linguists/NNS
#   theorise/VBP
#   that/IN
#   it/PRP
#   is/VBZ
#   largely/RB
#   a/DT
#   product/NN
#   of/IN
#   the/DT
#   millennia-old/JJ
#   Confucian/JJ
#   notion/NN
#   of/IN
#   harmony/NN
#   ,/,
#   which/WDT
#   centres/VBZ
#   on/IN
#   maintaining/VBG
#   interpersonal/JJ
#   relationships/NNS
#   rather/RB
#   than/IN
#   individual/JJ
#   ones/NNS
#   ./.
#   Preserving/VBG
#   social/JJ
#   cohesion/NN
#   at/IN
#   all/DT
#   costs/NNS
#   is/VBZ
#   still/RB
#   the/DT
#   bedrock/NN
#   of/IN
#   (GPE Taiwan/NNP)
#   ’/NNP
#   s/VBZ
#   social/JJ
#   morality/NN
#   ;/:
#   placing/VBG
#   the/DT
#   larger/JJR
#   clan/NN
#   ,/,
#   the/DT
#   society/NN
#   ,/,
#   before/IN
#   yourself/PRP
#   ,/,
#   the/DT
#   individual/NN
#   ,/,
#   is/VBZ
#   key/JJ
#   ./.
#   In/IN
#   addition/NN
#   ,/,
#   part/NN
#   of/IN
#   (GPE Taiwan/NNP)
#   's/POS
#   buhaoyisi/JJ
#   culture/NN
#   is/VBZ
#   heavily/RB
#   influenced/VBN
#   from/IN
#   (GPE Japan/NNP)
#   ’/NNP
#   s/VBD
#   sumimasen/JJ
#   apology/JJ
#   culture/NN
#   ,/,
#   with/IN
#   the/DT
#   two/CD
#   sharing/VBG
#   a/DT
#   deep/JJ
#   history/NN
#   ./.
#   Overall/JJ
#   ,/,
#   as/IN
#   a/DT
#   habit/NN
#   ,/,
#   saying/VBG
#   buhaoyisi/NN
#   often/RB
#   helps/VBZ
#   confrontations/NNS
#   from/IN
#   escalating/VBG
#   further/RB
#   ,/,
#   (PERSON Li/NNP)
#   said/VBD
#   ./.
#   “/JJ
#   Traditional/NNP
#   Taiwanese/JJ
#   culture/NN
#   is/VBZ
#   like/IN
#   that/DT
#   –/VBZ
#   more/JJR
#   delicate/JJ
#   and/CC
#   thinking/NN
#   of/IN
#   other/JJ
#   people/NNS
#   ,/,
#   trying/VBG
#   to/TO
#   keep/VB
#   polite/JJ
#   relationships/NNS
#   with/IN
#   others/NNS
#   ,/,
#   ”/VB
#   he/PRP
#   explained/VBD
#   ./.
#   The/DT
#   culture/NN
#   of/IN
#   buhaoyisi/NN
#   reveals/NNS
#   a/DT
#   lot/NN
#   about/IN
#   (GPE Taiwan/NNP)
#   ’/NNP
#   s/VBD
#   hidden/JJ
#   layers/NNS
#   of/IN
#   modesty/NN
#   and/CC
#   shyness/NN
#   (/(
#   (ORGANIZATION Credit/NNP)
#   :/:
#   Credit/NN
#   :/:
#   (PERSON Sean/JJ Pavone/Alamy/NNP)
#   )/)
#   The/DT
#   culture/NN
#   of/IN
#   buhaoyisi/NN
#   reveals/NNS
#   a/DT
#   lot/NN
#   about/IN
#   (GPE Taiwan/NNP)
#   ’/NNP
#   s/VBD
#   hidden/JJ
#   layers/NNS
#   of/IN
#   modesty/NN
#   and/CC
#   shyness/NN
#   (/(
#   (ORGANIZATION Credit/NNP)
#   :/:
#   (PERSON Sean/JJ Pavone/Alamy/NNP)
#   )/)
#   On/IN
#   the/DT
#   one/CD
#   hand/NN
#   ,/,
#   the/DT
#   expression/NN
#   carries/VBZ
#   an/DT
#   air/NN
#   of/IN
#   submissiveness/NN
#   and/CC
#   hyper/NN
#   decorum/NN
#   ,/,
#   but/CC
#   on/IN
#   the/DT
#   other/JJ
#   hand/NN
#   ,/,
#   it/PRP
#   also/RB
#   demonstrates/VBZ
#   the/DT
#   unparalleled/JJ
#   politeness/NN
#   of/IN
#   (GPE Taiwan/NNP)
#   ./.
#   That/DT
#   's/VBZ
#   why/WRB
#   ,/,
#   for/IN
#   the/DT
#   traveller/NN
#   ,/,
#   saying/VBG
#   sorry/NN
#   in/IN
#   (GPE Chinese/JJ)
#   can/MD
#   easily/RB
#   turn/VB
#   into/IN
#   a/DT
#   linguistic/JJ
#   minefield/NN
#   ./.
#   When/WRB
#   in/IN
#   doubt/NN
#   ,/,
#   (PERSON Li/NNP)
#   says/VBZ
#   ,/,
#   err/NN
#   on/IN
#   the/DT
#   safe/JJ
#   side/NN
#   and/CC
#   just/RB
#   say/VB
#   buhaoyisi/NN
#   ;/:
#   chances/NNS
#   are/VBP
#   they/PRP
#   ’/JJ
#   ll/NNS
#   say/VBP
#   buhaoyisi/NN
#   back/RB
#   to/TO
#   you/PRP
#   ./.
#   It/PRP
#   ’/VBZ
#   s/PDT
#   the/DT
#   unspoken/JJ
#   rule/NN
#   on/IN
#   the/DT
#   islands/NNS
#   of/IN
#   (GPE Taiwan/NNP)
#   ./.
#   (PERSON Li/NNP)
#   also/RB
#   suggests/VBZ
#   that/IN
#   this/DT
#   culture/NN
#   of/IN
#   buhaoyisi/NN
#   is/VBZ
#   unique/JJ
#   to/TO
#   (GPE Taiwan/NNP)
#   ,/,
#   as/IN
#   opposed/VBN
#   to/TO
#   the/DT
#   rest/NN
#   of/IN
#   the/DT
#   Chinese-speaking/NNP
#   world/NN
#   ;/:
#   while/IN
#   you/PRP
#   'll/MD
#   hear/VB
#   buhaoysi/RB
#   many/JJ
#   times/NNS
#   over/IN
#   throughout/IN
#   the/DT
#   streets/NNS
#   of/IN
#   (GPE Taiwan/NNP)
#   ,/,
#   you/PRP
#   are/VBP
#   less/RBR
#   likely/JJ
#   to/TO
#   hear/VB
#   buhaoyisi/NN
#   being/VBG
#   used/VBN
#   in/IN
#   this/DT
#   way/NN
#   in/IN
#   (GPE China/NNP)
#   or/CC
#   (GPE Malaysia/NNP)
#   ,/,
#   which/WDT
#   place/VBP
#   less/JJR
#   emphasis/NN
#   on/IN
#   such/JJ
#   polite-isms/NNS
#   ./.
#   When/WRB
#   in/IN
#   doubt/NN
#   ,/,
#   err/NN
#   on/IN
#   the/DT
#   safe/JJ
#   side/NN
#   and/CC
#   just/RB
#   say/VB
#   buhaoyisi/UH
#   According/VBG
#   to/TO
#   (ORGANIZATION InterNations/NNP)
#   ’/NNP
#   Expat/NNP
#   Insider/NNP
#   Index/NNP
#   ,/,
#   (GPE Taiwan/NNP)
#   is/VBZ
#   consistently/RB
#   ranked/VBN
#   as/IN
#   one/CD
#   of/IN
#   the/DT
#   world/NN
#   ’/NNP
#   s/NN
#   friendliest/NN
#   countries/NNS
#   ./.
#   Around/IN
#   90/CD
#   %/NN
#   of/IN
#   expats/NNS
#   in/IN
#   (GPE Taiwan/NNP)
#   gave/VBD
#   residents/NNS
#   high/JJ
#   marks/NNS
#   for/IN
#   hospitality/NN
#   ,/,
#   compared/VBN
#   to/TO
#   a/DT
#   combined/JJ
#   average/NN
#   of/IN
#   65/CD
#   %/NN
#   in/IN
#   the/DT
#   rest/NN
#   of/IN
#   the/DT
#   surveyed/JJ
#   countries/NNS
#   ./.
#   Nowadays/CC
#   ,/,
#   more/JJR
#   than/IN
#   one-third/NN
#   of/IN
#   expats/NNS
#   are/VBP
#   considering/VBG
#   staying/VBG
#   on/IN
#   the/DT
#   tiny/JJ
#   (GPE Pacific/NNP)
#   island/NN
#   forever/RB
#   ,/,
#   according/VBG
#   to/TO
#   the/DT
#   survey/NN
#   of/IN
#   12,500-plus/JJ
#   respondents/NNS
#   around/IN
#   the/DT
#   world/NN
#   ./.
#   The/DT
#   secret/JJ
#   to/TO
#   attracting/VBG
#   people/NNS
#   to/TO
#   the/DT
#   lush/NN
#   ,/,
#   tropical/JJ
#   islands/NNS
#   of/IN
#   (GPE Taiwan/NNP)
#   is/VBZ
#   really/RB
#   no/DT
#   secret/NN
#   at/IN
#   all/DT
#   –/NNP
#   just/RB
#   be/VB
#   ,/,
#   well/UH
#   ,/,
#   nice/JJ
#   ./.
#   However/RB
#   ,/,
#   according/VBG
#   to/TO
#   25-year-old/JJ
#   pharmacist/NN
#   Jieru/NNP
#   You/PRP
#   ,/,
#   who/WP
#   lives/VBZ
#   in/IN
#   the/DT
#   port/JJ
#   city/NN
#   of/IN
#   (GPE Kaohsiung/NNP)
#   ,/,
#   this/DT
#   nice/JJ
#   ,/,
#   little/JJ
#   narrative/JJ
#   that/IN
#   (GPE Taiwan/NNP)
#   is/VBZ
#   leading/VBG
#   the/DT
#   world/NN
#   in/IN
#   friendliness/NN
#   may/MD
#   be/VB
#   a/DT
#   false/JJ
#   one/CD
#   ,/,
#   or/CC
#   at/IN
#   least/JJS
#   not/RB
#   the/DT
#   full/JJ
#   picture/NN
#   ./.
#   Having/VBG
#   to/TO
#   make/VB
#   yourself/PRP
#   smaller/JJR
#   and/CC
#   apologise/VB
#   constantly/RB
#   for/IN
#   small/JJ
#   inconveniences/NNS
#   ,/,
#   and/CC
#   sometimes/RB
#   even/RB
#   your/PRP$
#   mere/JJ
#   presence/NN
#   ,/,
#   can/MD
#   ultimately/RB
#   do/VB
#   more/JJR
#   harm/NN
#   than/IN
#   help/NN
#   ./.
#   And/CC
#   ironically/RB
#   ,/,
#   asking/VBG
#   permission/NN
#   to/TO
#   do/VB
#   ,/,
#   to/TO
#   speak/VB
#   ,/,
#   to/TO
#   come/VB
#   and/CC
#   to/TO
#   go/VB
#   all/PDT
#   the/DT
#   time/NN
#   can/MD
#   be/VB
#   unnecessarily/RB
#   inconveniencing/VBG
#   yourself/PRP
#   more/JJR
#   than/IN
#   anyone/NN
#   else/RB
#   ./.
#   “/NN
#   When/WRB
#   making/VBG
#   a/DT
#   request/NN
#   to/TO
#   someone/NN
#   else/RB
#   ,/,
#   (GPE Taiwanese/JJ)
#   people/NNS
#   will/MD
#   often/RB
#   use/VB
#   buhaoyisi/NN
#   as/IN
#   a/DT
#   lead-in/NN
#   to/TO
#   express/VB
#   their/PRP$
#   desire/NN
#   to/TO
#   ask/VB
#   for/IN
#   help/NN
#   from/IN
#   a/DT
#   place/NN
#   of/IN
#   humble/JJ
#   submission/NN
#   ,/,
#   ”/NNP
#   You/PRP
#   said/VBD
#   ./.
#   As/IN
#   a/DT
#   matter/NN
#   of/IN
#   fact/NN
#   ,/,
#   he/PRP
#   was/VBD
#   already/RB
#   feeling/VBG
#   a/DT
#   bit/NN
#   ‘/JJ
#   buhaoyisi/NN
#   ’/NNP
#   –/NNP
#   embarrassed/VBD
#   to/TO
#   be/VB
#   interviewed/VBN
#   at/IN
#   all/DT
#   –/NNP
#   before/IN
#   diving/VBG
#   into/IN
#   his/PRP$
#   thoughts/NNS
#   ./.
#   Decades/NNS
#   of/IN
#   (GPE Japanese/JJ)
#   colonisation/NN
#   and/CC
#   the/DT
#   moral/JJ
#   teachings/NNS
#   of/IN
#   (ORGANIZATION Confucianism/NNP)
#   played/VBD
#   a/DT
#   hand/NN
#   in/IN
#   shaping/VBG
#   (GPE Taiwan/NNP)
#   ’/NNP
#   s/VBD
#   apology/JJ
#   culture/NN
#   (/(
#   (ORGANIZATION Credit/NNP)
#   :/:
#   Credit/NN
#   :/:
#   WorldFoto/Alamy/NNP
#   )/)
#   Decades/NNP
#   of/IN
#   (GPE Japanese/JJ)
#   colonisation/NN
#   ,/,
#   as/RB
#   well/RB
#   as/IN
#   moral/JJ
#   teachings/NNS
#   of/IN
#   (GSP Confucianism/NNP)
#   ,/,
#   have/VBP
#   played/VBN
#   a/DT
#   huge/JJ
#   hand/NN
#   in/IN
#   shaping/VBG
#   (GPE Taiwan/NNP)
#   ’/NNP
#   s/VBD
#   extreme/JJ
#   apology/JJ
#   culture/NN
#   (/(
#   (ORGANIZATION Credit/NN)
#   :/:
#   WorldFoto/Alamy/NNP
#   )/)
#   The/DT
#   concept/NN
#   of/IN
#   ‘/NNP
#   saving/VBG
#   face/NN
#   ’/NNP
#   is/VBZ
#   a/DT
#   big/JJ
#   deal/NN
#   in/IN
#   (GPE Taiwan/NNP)
#   ./.
#   Imagine/VB
#   a/DT
#   chessboard/NN
#   of/IN
#   social/JJ
#   exchanges/NNS
#   ,/,
#   in/IN
#   which/WDT
#   everyone/NN
#   else/RB
#   ’/NNP
#   s/NN
#   moves/NNS
#   affects/VBZ
#   your/PRP$
#   next/JJ
#   one/NN
#   ./.
#   (PERSON Face/NN)
#   ,/,
#   in/IN
#   this/DT
#   case/NN
#   ,/,
#   is/VBZ
#   the/DT
#   social/JJ
#   currency/NN
#   that/WDT
#   allows/VBZ
#   you/PRP
#   to/TO
#   make/VB
#   friends/NNS
#   and/CC
#   foster/JJ
#   professional/JJ
#   connections/NNS
#   that/WDT
#   can/MD
#   lead/VB
#   you/PRP
#   to/TO
#   your/PRP$
#   next/JJ
#   big/JJ
#   job/NN
#   ,/,
#   an/DT
#   investment/NN
#   in/IN
#   your/PRP$
#   company/NN
#   or/CC
#   even/RB
#   a/DT
#   warm/JJ
#   introduction/NN
#   to/TO
#   your/PRP$
#   future/JJ
#   wife/NN
#   ./.
#   Without/IN
#   ‘/JJ
#   face/NN
#   ’/NNP
#   ,/,
#   people/NNS
#   are/VBP
#   less/RBR
#   likely/JJ
#   to/TO
#   trust/VB
#   you/PRP
#   or/CC
#   help/VB
#   you/PRP
#   get/VB
#   ahead/RB
#   in/IN
#   life/NN
#   ./.
#   The/DT
#   end/NN
#   game/NN
#   is/VBZ
#   to/TO
#   protect/VB
#   yourself/PRP
#   ,/,
#   your/PRP$
#   self-image/JJ
#   and/CC
#   your/PRP$
#   dignity/NN
#   and/CC
#   curry/VB
#   favour/NNS
#   with/IN
#   others/NNS
#   by/IN
#   reciprocating/VBG
#   their/PRP$
#   acts/NNS
#   of/IN
#   kindness/NN
#   ./.
#   That/DT
#   ’/VBD
#   s/JJ
#   why/WRB
#   (GPE Taiwan/NNP)
#   is/VBZ
#   confrontation-averse/JJ
#   ;/:
#   it/PRP
#   ’/VBZ
#   s/PRP
#   a/DT
#   country/NN
#   constantly/RB
#   striving/VBG
#   to/TO
#   avoid/VB
#   conflicts/NNS
#   and/CC
#   preserve/VB
#   harmony/NN
#   at/IN
#   all/DT
#   costs/NNS
#   ./.
#   But/CC
#   what/WP
#   happens/VBZ
#   when/WRB
#   fiercely/RB
#   following/VBG
#   that/IN
#   moral/JJ
#   compass/NN
#   goes/VBZ
#   awry/RB
#   ?/.
#   You/PRP
#   just/RB
#   might/MD
#   get/VB
#   something/NN
#   akin/JJ
#   to/TO
#   (GPE Taiwan/NNP)
#   ’/NNP
#   s/VBD
#   conundrum/NN
#   of/IN
#   over-apologising/NN
#   ./.
#   The/DT
#   end/NN
#   game/NN
#   is/VBZ
#   to/TO
#   protect/VB
#   yourself/PRP
#   ,/,
#   your/PRP$
#   self-image/JJ
#   and/CC
#   your/PRP$
#   dignity/NN
#   On/IN
#   the/DT
#   flipside/NN
#   ,/,
#   people/NNS
#   with/IN
#   ‘/NNP
#   thin/JJ
#   face/NN
#   ’/NNP
#   ,/,
#   meaning/VBG
#   a/DT
#   lack/NN
#   or/CC
#   loss/NN
#   of/IN
#   your/PRP$
#   social/JJ
#   reputation/NN
#   and/CC
#   status/NN
#   ,/,
#   try/VB
#   not/RB
#   to/TO
#   trouble/NN
#   others/NNS
#   for/IN
#   fear/NN
#   of/IN
#   inconveniencing/VBG
#   them/PRP
#   ,/,
#   and/CC
#   they/PRP
#   certainly/RB
#   do/VBP
#   n't/RB
#   like/VB
#   to/TO
#   lose/VB
#   face/NN
#   in/IN
#   public/JJ
#   ,/,
#   adds/VBZ
#   (PERSON Yang/NNP)
#   ./.
#   So/NNP
#   instead/RB
#   of/IN
#   standing/VBG
#   up/RP
#   ,/,
#   everyone/NN
#   sits/NNS
#   down/RP
#   and/CC
#   stays/VB
#   there/EX
#   while/IN
#   little/JJ
#   gets/VBZ
#   done/VBN
#   ./.
#   (PERSON Yang/NNP)
#   feels/NNS
#   like/IN
#   she/PRP
#   ’/VBD
#   s/JJ
#   drowning/NN
#   in/IN
#   a/DT
#   pool/NN
#   of/IN
#   too/RB
#   many/JJ
#   perfunctory/JJ
#   apologies/NNS
#   ,/,
#   in/IN
#   which/WDT
#   saying/VBG
#   buhaoyisi/NN
#   is/VBZ
#   more/JJR
#   of/IN
#   a/DT
#   habit/NN
#   than/IN
#   a/DT
#   word/NN
#   with/IN
#   deeper/JJR
#   meaning/NN
#   ./.
#   The/DT
#   result/NN
#   is/VBZ
#   half-hearted/JJ
#   ,/,
#   stripped/VBD
#   of/IN
#   any/DT
#   sincere/JJ
#   apology/NN
#   or/CC
#   regret/NN
#   ./.
#   Not/RB
#   to/TO
#   mention/VB
#   ,/,
#   thanks/NNS
#   to/TO
#   the/DT
#   island/NN
#   ’/NNP
#   s/NN
#   growing/VBG
#   global/JJ
#   isolation/NN
#   and/CC
#   economic/JJ
#   malaise/NN
#   ,/,
#   Taiwanese/EX
#   are/VBP
#   suffering/VBG
#   from/IN
#   the/DT
#   poetically/RB
#   named/VBN
#   syndrome/NN
#   of/IN
#   guidao/NN
#   ,/,
#   or/CC
#   ‘/VBZ
#   ghost/NN
#   island/NN
#   ’/NNP
#   ./.
#   (GPE Taiwan/NNP)
#   is/VBZ
#   confrontation-averse/JJ
#   ,/,
#   constantly/RB
#   striving/VBG
#   to/TO
#   avoid/VB
#   conflicts/NNS
#   and/CC
#   preserve/VB
#   harmony/NN
#   at/IN
#   all/DT
#   costs/NNS
#   (/(
#   (ORGANIZATION Credit/NNP)
#   :/:
#   Credit/NN
#   :/:
#   Keitma/Alamy/NNP
#   )/)
#   (GPE Taiwan/NNP)
#   is/VBZ
#   confrontation-averse/JJ
#   ,/,
#   constantly/RB
#   striving/VBG
#   to/TO
#   avoid/VB
#   conflicts/NNS
#   and/CC
#   preserve/VB
#   harmony/NN
#   at/IN
#   all/DT
#   costs/NNS
#   (/(
#   (ORGANIZATION Credit/NNP)
#   :/:
#   Keitma/Alamy/NNP
#   )/)
#   On/IN
#   the/DT
#   world/NN
#   stage/NN
#   ,/,
#   (GPE Taiwan/NNP)
#   ’/NNP
#   s/NN
#   identity/NN
#   is/VBZ
#   often/RB
#   misunderstood/VBN
#   ,/,
#   says/VBZ
#   (PERSON Wenhui/NNP Chen/NNP)
#   ,/,
#   informatics/NN
#   professor/NN
#   at/IN
#   (ORGANIZATION Ming/NNP Chuan/NNP University/NNP)
#   ,/,
#   who/WP
#   studies/NNS
#   the/DT
#   ghost-island/NN
#   phenomenon/NN
#   ./.
#   He/PRP
#   says/VBZ
#   that/IN
#   the/DT
#   island/NN
#   is/VBZ
#   often/RB
#   viewed/VBN
#   as/IN
#   a/DT
#   pawn/NN
#   between/IN
#   (GPE China/NNP)
#   and/CC
#   the/DT
#   (GSP US/NNP)
#   ,/,
#   floating/VBG
#   along/RB
#   without/IN
#   many/JJ
#   of/IN
#   the/DT
#   diplomatic/JJ
#   trappings/NNS
#   of/IN
#   an/DT
#   officially/RB
#   recognised/JJ
#   country/NN
#   ./.
#   (PERSON Chen/NNP)
#   predicts/VBZ
#   (GPE Taiwan/NNP)
#   ’/NNP
#   s/VBD
#   apologetic/JJ
#   ,/,
#   kow-towing/JJ
#   culture/NN
#   may/MD
#   not/RB
#   prove/VB
#   so/RB
#   fruitful/JJ
#   in/IN
#   the/DT
#   end/NN
#   ,/,
#   and/CC
#   could/MD
#   even/RB
#   lead/VB
#   to/TO
#   the/DT
#   society/NN
#   ’/NNP
#   s/VBD
#   own/JJ
#   undoing/NN
#   ./.
#   Of/IN
#   course/NN
#   ,/,
#   not/RB
#   everyone/NN
#   bears/NNS
#   such/JJ
#   a/DT
#   doom-and-gloom/JJ
#   forecast/NN
#   for/IN
#   (GPE Taiwan/NNP)
#   ./.
#   Li/NNP
#   ,/,
#   for/IN
#   his/PRP$
#   part/NN
#   ,/,
#   sees/VBZ
#   the/DT
#   island/NN
#   ’/NNP
#   s/VBZ
#   deep/JJ
#   buhaoyisi/JJ
#   culture/NN
#   as/IN
#   integral/JJ
#   to/TO
#   keeping/VBG
#   the/DT
#   peace/NN
#   –/NNP
#   and/CC
#   if/IN
#   the/DT
#   culture/NN
#   of/IN
#   buhaoyisi/NN
#   disappears/NNS
#   ,/,
#   then/RB
#   so/RB
#   will/MD
#   centuries/NNS
#   of/IN
#   timeworn/JJ
#   tradition/NN
#   ./.
#   “/VB
#   If/IN
#   the/DT
#   society/NN
#   keeps/VBZ
#   these/DT
#   concepts/NNS
#   and/CC
#   expresses/VBZ
#   these/DT
#   words/NNS
#   daily/RB
#   ,/,
#   then/RB
#   the/DT
#   society/NN
#   could/MD
#   be/VB
#   more/JJR
#   polite/JJ
#   ,/,
#   more/RBR
#   moral/JJ
#   and/CC
#   more/RBR
#   conservative/JJ
#   ,/,
#   ”/JJ
#   (PERSON Li/NNP)
#   said/VBD
#   ./.
#   “/VB
#   If/IN
#   not/RB
#   ,/,
#   the/DT
#   society/NN
#   becomes/VBZ
#   impolite/RB
#   ,/,
#   immoral/JJ
#   and/CC
#   too/RB
#   aggressive/JJ
#   ./.
#   (PERSON Taiwan/NNP)
#   ’/NNP
#   s/JJ
#   culture/NN
#   [/NN
#   must/MD
#   ]/VB
#   be/VB
#   kept/VBN
#   in/IN
#   a/DT
#   good/JJ
#   shape/NN
#   in/IN
#   terms/NNS
#   of/IN
#   morality/NN
#   and/CC
#   harmony./NN
#   ”/NN
#   He/PRP
#   then/RB
#   ended/VBD
#   with/IN
#   the/DT
#   obligatory/NN
#   ‘/NNP
#   buhaoyisi/NN
#   ’/NN
#   ./.)

# %%
def get_continuous_chunks(text, label):
    chunked = ne_chunk(pos_tag(word_tokenize(text)))
    prev = None
    continuous_chunk = []
    current_chunk = []

    for subtree in chunked:
        if type(subtree) == Tree and subtree.label() == label:
            current_chunk.append(" ".join([token for token, pos in subtree.leaves()]))
        elif current_chunk:
            named_entity = " ".join(current_chunk)
            if named_entity not in continuous_chunk:
                continuous_chunk.append(named_entity)
                current_chunk = []
        else:
            continue

    return continuous_chunk

# %%
get_continuous_chunks(strEx, 'GPE')
# Out:
# ['Taiwan',
#  'Taiwan Taiwan',
#  'Taiwan Japan',
#  'Taiwanese',
#  'Chinese',
#  'New York',
#  'Taiwan German',
#  'English',
#  'Chinese Taiwanese',
#  'Taipei',
#  'Taiwan Taiwan Taiwan',
#  'Japanese',
#  'Taiwan Taiwan Taiwan Japan',
#  'Taiwan Taiwan Taiwan Chinese',
#  'Taiwan Taiwan Taiwan China',
#  'Malaysia',
#  'Taiwan Taiwan Pacific',
#  'Taiwan Kaohsiung',
#  'Taiwan Taiwanese',
#  'Japanese Taiwan',
#  'Japanese Taiwan Taiwan',
#  'Taiwan Taiwan Taiwan Taiwan',
#  'Taiwan China']

# %%
get_continuous_chunks(strEx, 'ORGANIZATION')
# Out:
# ['Pandora',
#  'Pandora Brooklyn College City University',
#  'National Taiwan University',
#  'Language Division',
#  'Credit',
#  'Credit National Taiwan Normal University',
#  'Credit Credit',
#  'InterNations',
#  'Confucianism',
#  'Credit Credit Credit',
#  'Credit Ming Chuan University']

# %%
get_continuous_chunks(strEx, 'PERSON')
# Out:
# ['Leslie',
#  'Joanne Chen',
#  'Lee',
#  'Chen',
#  'Lee Buhaoyisi',
#  'Prof',
#  'Buhaoyisi',
#  'Ouyu Yang',
#  'Buhaoyisi James',
#  'James',
#  'Li',
#  'Li Sean Pavone/Alamy',
#  'Sean Pavone/Alamy',
#  'Li Li',
#  'Face',
#  'Yang',
#  'Yang Wenhui Chen',
#  'Chen Li',
#  'Taiwan']
